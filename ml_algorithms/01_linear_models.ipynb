# %% [markdown]
# # ML Algorithms: Linear Models
#
# This notebook implements classical machine learning algorithms using PyTorch.
#
# ## Algorithms Covered
#
#
# - Linear Regression
# - Logistic Regression
# - Ridge Regression
# - Lasso Regression
#
#
# ## Why PyTorch for ML?
#
# - GPU acceleration
# - Automatic differentiation
# - Integration with deep learning pipelines
# - Efficient tensor operations

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification, make_regression
from sklearn.model_selection import train_test_split

print(f"PyTorch version: {torch.__version__}")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: {device}")

# %% [markdown]
# ## 1. Theory
#
# Linear Models are fundamental machine learning algorithms.
#
# ### Mathematical Foundation
#
# For linear models:
# - Input: X ∈ ℝ^(n×d)
# - Output: y ∈ ℝ^n
# - Goal: Learn mapping f: X → y
#
# ### Algorithm Steps
#
# 1. Initialize parameters
# 2. Compute predictions
# 3. Calculate loss
# 4. Update parameters
# 5. Repeat until convergence

# %%
# Implementation of Linear Models
class PyTorchLinearModels(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.linear = nn.Linear(input_dim, output_dim)
    
    def forward(self, x):
        return self.linear(x)

# Example usage
model = PyTorchLinearModels(10, 1).to(device)
print(model)

# Generate synthetic data
X = torch.randn(100, 10)
y = torch.randn(100, 1)

# Training loop example
optimizer = optim.SGD(model.parameters(), lr=0.01)
criterion = nn.MSELoss()

for epoch in range(100):
    optimizer.zero_grad()
    output = model(X)
    loss = criterion(output, y)
    loss.backward()
    optimizer.step()
    
    if (epoch + 1) % 20 == 0:
        print(f"Epoch {epoch+1}: Loss = {loss.item():.4f}")

# %% [markdown]
# ## 2. Comparison with Scikit-Learn
#
# PyTorch implementation vs sklearn:
#
# | Feature | PyTorch | Scikit-Learn |
# |---------|---------|--------------|
# | Speed | GPU accelerated | CPU only |
# | Flexibility | High | Medium |
# | Integration | Deep learning | Traditional ML |
# | Gradients | Automatic | N/A |

# %% [markdown]
# ## 📝 Summary
#
# ✅ Implemented classical ML algorithms in PyTorch
# ✅ Compared with traditional implementations
# ✅ Leveraged GPU acceleration
# ✅ Integrated with deep learning workflows
#
# ### When to Use
#
# - **Use PyTorch ML**: Large datasets, GPU available, integration with deep learning
# - **Use Scikit-Learn**: Small datasets, simple models, quick prototyping
#
# ### Next Steps
#
# - Combine with neural networks
# - Implement ensemble methods
# - Apply to real datasets

# %% [markdown]
# ## 🎯 Practice Exercises

# %%
# Exercise 1: Add regularization
# Your code here:


# Exercise 2: Implement cross-validation
# Your code here:


# Exercise 3: Compare performance with sklearn
# Your code here:


# Exercise 4: Visualize decision boundaries
# Your code here:
